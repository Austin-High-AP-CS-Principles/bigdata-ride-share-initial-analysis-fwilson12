# %% [markdown]
# # Ride Share Dataset

# %% [markdown]
# **Ride Share(Boston) Dataset Glossary**
#
# |Variable|Description|
# |---|---|
# |Distance|Distance Between Source and Destination|
# |cab_type|Uber or Lyft|
# |time_stamp|epoch time when data was queried|
# |destination|destination of the ride|
# |source|the starting point of the ride|
# |price|price estimated for the ride in USD|
# |surge_multiplier|the multiplier by which price was increased, default 1|
# |id|unique identifier|
# |product_id|uber/lyft identifier for cab-type|
# |name|visible type of the cab eg: Uber Pool, UberXL|

# %% [markdown]
# # **Import Libraries and Dataset**

# %% [markdown]
# ## Import Libraries

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# to restrict the float value to 3 decimal places
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Import Dataset

# %%
#import data as a pandas dataframe

# Access the .csv file in Google Drive folder. The file path must be correct
data = pd.read_csv('cab_rides.csv')

# %% [markdown]
# # **Data Check**

# %% [markdown]
# ### View the first five and last five rows of the dataframe

# %% [markdown]
# ### Determine the number of entries in the dataframe

# %% [markdown]
# ### Check the data types for each entry

# %%
data
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0          0.440     Lyft  1544952607890  North Station  Haymarket Square
# 1          0.440     Lyft  1543284023677  North Station  Haymarket Square
# 2          0.440     Lyft  1543366822198  North Station  Haymarket Square
# 3          0.440     Lyft  1543553582749  North Station  Haymarket Square
# 4          0.440     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066     1.000     Uber  1543708385534      North End          West End
# 693067     1.000     Uber  1543708385534      North End          West End
# 693068     1.000     Uber  1543708385534      North End          West End
# 693069     1.000     Uber  1543708385534      North End          West End
# 693070     1.000     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0       5.000             1.000  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1      11.000             1.000  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2       7.000             1.000  981a3613-77af-4620-a42a-0c0866077d1e
# 3      26.000             1.000  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4       9.000             1.000  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693066 13.000             1.000  616d3611-1820-450a-9845-a9ff304a4842
# 693067  9.500             1.000  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693068    NaN             1.000  64d451d0-639f-47a4-9b7c-6fd92fbd264f
# 693069 27.000             1.000  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070 10.000             1.000  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
# [693071 rows x 10 columns]

# %%
data.shape
# Out:
# (693071, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  int64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 52.9+ MB

# %% [markdown]
# Convert "timestamp" to a datetime datatype

# %%
#Convert "timestamp" to a datetime datatype
data['date'] = pd.to_datetime(data['time_stamp'],unit='ms')
data = data.drop(['time_stamp'], axis=1)
data
# Out:
#         distance cab_type    destination            source  price  \
# 0          0.440     Lyft  North Station  Haymarket Square  5.000
# 1          0.440     Lyft  North Station  Haymarket Square 11.000
# 2          0.440     Lyft  North Station  Haymarket Square  7.000
# 3          0.440     Lyft  North Station  Haymarket Square 26.000
# 4          0.440     Lyft  North Station  Haymarket Square  9.000
# ...          ...      ...            ...               ...    ...
# 693066     1.000     Uber      North End          West End 13.000
# 693067     1.000     Uber      North End          West End  9.500
# 693068     1.000     Uber      North End          West End    NaN
# 693069     1.000     Uber      North End          West End 27.000
# 693070     1.000     Uber      North End          West End 10.000
#
#         surge_multiplier                                    id  \
# 0                  1.000  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1                  1.000  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2                  1.000  981a3613-77af-4620-a42a-0c0866077d1e
# 3                  1.000  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4                  1.000  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...                  ...                                   ...
# 693066             1.000  616d3611-1820-450a-9845-a9ff304a4842
# 693067             1.000  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693068             1.000  64d451d0-639f-47a4-9b7c-6fd92fbd264f
# 693069             1.000  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070             1.000  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                           date
# 0      2018-12-16 09:30:07.890
# 1      2018-11-27 02:00:23.677
# 2      2018-11-28 01:00:22.198
# 3      2018-11-30 04:53:02.749
# 4      2018-11-29 03:49:20.223
# ...                        ...
# 693066 2018-12-01 23:53:05.534
# 693067 2018-12-01 23:53:05.534
# 693068 2018-12-01 23:53:05.534
# 693069 2018-12-01 23:53:05.534
# 693070 2018-12-01 23:53:05.534
#
# [693071 rows x 10 columns]

# %%
# Bin datetime to hours
data['hourly_bins'] = pd.cut(data['date'], bins=pd.date_range(start=data['date'].min(), end=data['date'].max(), freq='H'))
data['hours'] = data['hourly_bins'].apply(lambda x: x.left.hour)
data = data.drop('hourly_bins', axis=1)
map = {0.000:"12:00AM",1.000:"1:00AM",2.000:"2:00AM",3.000:"3:00AM",4.000:"4:00AM",5.000:"5:00AM",6.000:"6:00AM",7.000:"7:00AM",8.000:"8:00AM",9.000:"9:00AM",10.000:"10:00AM",11.000:"11:00AM",12.000:"12:00PM",13.000:"1:00PM",14.000:"2:00PM",15.000:"3:00PM",16.000:"4:00PM",17.000:"5:00PM",18.000:"6:00PM",19.000:"7:00PM",20.000:"8:00PM",21.000:"9:00PM",22.000:"10:00PM",23.000:"11:00PM",24.000:"12:00PM"}
data["hours"].replace(map, inplace=True)
data
# Out:
#         distance cab_type    destination            source  price  \
# 0          0.440     Lyft  North Station  Haymarket Square  5.000
# 1          0.440     Lyft  North Station  Haymarket Square 11.000
# 2          0.440     Lyft  North Station  Haymarket Square  7.000
# 3          0.440     Lyft  North Station  Haymarket Square 26.000
# 4          0.440     Lyft  North Station  Haymarket Square  9.000
# ...          ...      ...            ...               ...    ...
# 693066     1.000     Uber      North End          West End 13.000
# 693067     1.000     Uber      North End          West End  9.500
# 693068     1.000     Uber      North End          West End    NaN
# 693069     1.000     Uber      North End          West End 27.000
# 693070     1.000     Uber      North End          West End 10.000
#
#         surge_multiplier                                    id  \
# 0                  1.000  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1                  1.000  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2                  1.000  981a3613-77af-4620-a42a-0c0866077d1e
# 3                  1.000  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4                  1.000  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...                  ...                                   ...
# 693066             1.000  616d3611-1820-450a-9845-a9ff304a4842
# 693067             1.000  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693068             1.000  64d451d0-639f-47a4-9b7c-6fd92fbd264f
# 693069             1.000  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070             1.000  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                           date    hours
# 0      2018-12-16 09:30:07.890   8:00AM
# 1      2018-11-27 02:00:23.677   1:00AM
# 2      2018-11-28 01:00:22.198  12:00AM
# 3      2018-11-30 04:53:02.749   4:00AM
# 4      2018-11-29 03:49:20.223   3:00AM
# ...                        ...      ...
# 693066 2018-12-01 23:53:05.534  11:00PM
# 693067 2018-12-01 23:53:05.534  11:00PM
# 693068 2018-12-01 23:53:05.534  11:00PM
# 693069 2018-12-01 23:53:05.534  11:00PM
# 693070 2018-12-01 23:53:05.534  11:00PM
#
# [693071 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   destination       693071 non-null  object
#  3   source            693071 non-null  object
#  4   price             637976 non-null  float64
#  5   surge_multiplier  693071 non-null  float64
#  6   id                693071 non-null  object
#  7   product_id        693071 non-null  object
#  8   name              693071 non-null  object
#  9   date              693071 non-null  datetime64[ns]
#  10  hours             691978 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 58.2+ MB

# %% [markdown]
# ### Check for missing values

# %%
data.isnull().sum()
# Out:
# distance                0
# cab_type                0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# date                    0
# hours                1093
# dtype: int64

# %% [markdown]
# ### Check for duplicate values and remove duplicate values if any exist

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Create a statistical summary of the numerical data

# %%
data.describe().T
# Out:
#                       count                           mean  \
# distance         693071.000                          2.189
# price            637976.000                         16.545
# surge_multiplier 693071.000                          1.014
# date                 693071  2018-12-05 21:35:09.764357120
#
#                                          min                            25%  \
# distance                               0.020                          1.280
# price                                  2.500                          9.000
# surge_multiplier                       1.000                          1.000
# date              2018-11-26 03:40:46.318000  2018-11-28 22:26:08.356499968
#
#                                             50%  \
# distance                                  2.160
# price                                    13.500
# surge_multiplier                          1.000
# date              2018-12-02 07:57:57.528999936
#
#                                             75%                         max  \
# distance                                  2.920                       7.860
# price                                    22.500                      97.500
# surge_multiplier                          1.000                       3.000
# date              2018-12-14 22:45:08.976499968  2018-12-18 19:15:10.943000
#
#                    std
# distance         1.139
# price            9.324
# surge_multiplier 0.092
# date               NaN

# %% [markdown]
# # **Initial Analysis**

# %% [markdown]
# ### Question 1: During which hours of the day do the majority of individuals utilize ride-sharing services?

# %%
data["hours"].value_counts(normalize = True)*100
# Out:
# hours
# 11:00PM   4.665
# 10:00PM   4.587
# 9:00AM    4.504
# 10:00AM   4.391
# 11:00AM   4.391
# 12:00PM   4.391
# 1:00PM    4.391
# 3:00PM    4.391
# 4:00PM    4.391
# 5:00PM    4.391
# 2:00PM    4.391
# 12:00AM   4.371
# 3:00AM    4.250
# 1:00AM    4.171
# 9:00PM    4.096
# 6:00PM    3.985
# 8:00PM    3.940
# 2:00AM    3.915
# 5:00AM    3.881
# 7:00PM    3.845
# 8:00AM    3.764
# 6:00AM    3.695
# 4:00AM    3.685
# 7:00AM    3.520
# Name: proportion, dtype: float64

# %% [markdown]
# ### Question 2: Which ride-sharing service generated the highest profit within the 2018 timeframe? Additionally, what was the average ride price for each of the ride-sharing services?

# %%
data[data['date'].dt.year == 2018].groupby(['cab_type'], as_index=False)['price'].agg(['sum','mean'])
# Out:
#   cab_type         sum   mean
# 0     Lyft 5333957.980 17.351
# 1     Uber 5221435.000 15.795

# %% [markdown]
# ### Question 3: What is the average price per mile for rides with Uber and those with Lyft in Boston?

# %%
data["price/mile"] = data["price"] / data["distance"]
data.groupby(['cab_type'], as_index=False)['price/mile'].agg(['mean'])
# Out:
#   cab_type  mean
# 0     Lyft 9.683
# 1     Uber 9.692

# %% [markdown]
# ### Question 4: How many more miles did Uber drivers drive than Lyft riders? What were the average distances travelled by both services?

# %%
diff = data[data['cab_type']== 'Uber']['distance'].sum() - data[data['cab_type']== 'Lyft']['distance'].sum() 
data.groupby(['cab_type'], as_index=False)['distance'].agg(['sum','mean'])
# Out:
#   cab_type        sum  mean
# 0     Lyft 672293.790 2.187
# 1     Uber 845136.480 2.191

# %%
print('Uber drivers drove',int(diff),"more miles than Lyft drivers in total.")
# Out:
# Uber drivers drove 172842 more miles than Lyft drivers in total.

# %% [markdown]
# ### Question 5: Which departure -> destination combo is the most popular?

# %%
data.groupby(['source'], as_index=False)['destination'].value_counts(normalize=True)
# Out:
#       source              destination  proportion
# 0   Back Bay                North End       0.177
# 1   Back Bay         Haymarket Square       0.166
# 2   Back Bay  Northeastern University       0.166
# 3   Back Bay            South Station       0.164
# 4   Back Bay                   Fenway       0.164
# ..       ...                      ...         ...
# 67  West End        Boston University       0.173
# 68  West End            South Station       0.166
# 69  West End  Northeastern University       0.166
# 70  West End                North End       0.160
# 71  West End         Haymarket Square       0.159
#
# [72 rows x 3 columns]
